# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_sas("./data/three.sas7bdat")

# %%
data.head()
# Out:
#    YEAR  DATANUM  STATEFIP   SLWT   AGE  BPLG  HISPANG  EDUCREC  EDUC99  \
# 0  95.0      1.0       1.0  327.0  58.0   1.0      NaN      2.0     NaN
# 1  95.0      1.0       1.0  327.0  58.0   1.0      NaN      2.0     NaN
# 2  95.0      1.0       1.0  326.0  58.0   1.0      NaN      3.0     NaN
# 3  95.0      1.0       1.0  327.0  58.0   1.0      NaN      3.0     NaN
# 4  95.0      1.0       1.0  327.0  58.0   1.0      NaN      3.0     NaN
#
#    EMPSTATG  ...  YEARAT14  TREQSCHL  HAVECSL  SOUTH  _TYPE_  _FREQ_  \
# 0       1.0  ...    1906.0       NaN      0.0    1.0     0.0  3306.0
# 1       1.0  ...    1906.0       NaN      0.0    1.0     0.0  3306.0
# 2       1.0  ...    1906.0       NaN      0.0    1.0     0.0  3306.0
# 3       1.0  ...    1906.0       NaN      0.0    1.0     0.0  3306.0
# 4       1.0  ...    1906.0       NaN      0.0    1.0     0.0  3306.0
#
#    SIMPCOMP   SIMPCAP    WTCOMP     WTCAP
# 0  8.146345  8.146345  8.226838  8.226838
# ...

# %%
for i in data.columns:
    print('####-------------------------####')
    print(data[f"{i}"].describe().round(3))
    print("####-------------------------####")
    print("\n")
# Out:
# ####-------------------------####
# count    3820685.000
# mean          97.693
# std            0.887
# min           95.000
# 25%           97.000
# 50%           98.000
# 75%           98.000
# max           99.000
# Name: YEAR, dtype: float64
# ####-------------------------####
#
#
# ####-------------------------####
# count    3820685.000
# mean           1.472
# std            1.004
# min            1.000
# 25%            1.000
# 50%            1.000
# 75%            1.000
# max            4.000
# Name: DATANUM, dtype: float64
# ####-------------------------####
#
#
# ####-------------------------####
# count    3820685.000
# mean          28.845
# std           15.294
# min            1.000
# 25%           17.000
# 50%           29.000
# 75%           42.000
# max           56.000
# Name: STATEFIP, dtype: float64
# ####-------------------------####
#
#
# ####-------------------------####
# count    3820685.000
# mean          50.146
# std           54.062
# ...

# %% [markdown]
# |Variable| name | description |
# |--------|------|-------------|
# |Age     | AGE  | age         |
# |Individual education|GRADCAP| years of schooling capped 17|

# %%
data.YEAR.drop_duplicates()
# Out:
# 0        95.0
# 371      96.0
# 2428     97.0
# 8437     98.0
# 24524    99.0
# Name: YEAR, dtype: float64
